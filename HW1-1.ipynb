# %% [markdown]
# # 📝 Homework #1

# %% [markdown]
# Imagine we are interested in predicting penguins species based on two of their
# body measurements: culmen length and culmen depth. First we want to do some
# data exploration to get a feel for the data.
#
# What are the features? What is the target?

# %% [markdown]
# The data is located in `penguins.csv`, load it with
# `pandas` into a `DataFrame`.

# %%
# Write your code here.
import pandas as pd
penguins = pd.read_csv('penguins.csv')

# %% [markdown]
# Show a few samples of the data.
#
# How many features are numerical?

# %%
# Write your code here.
penguins.head()
# 6 are of d_type numeric.- rowid, boll_length, bill_depth, flipper_lenth, body_mass, year
# Out:
#    rowid species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      1  Adelie  Torgersen            39.1           18.7              181.0
# 1      2  Adelie  Torgersen            39.5           17.4              186.0
# 2      3  Adelie  Torgersen            40.3           18.0              195.0
# 3      4  Adelie  Torgersen             NaN            NaN                NaN
# 4      5  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %% [markdown]
# What are the different penguins species available in the dataset and how many
# samples of each species are there? Hint: select the right column and use the
# [`value_counts`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html)
# method.

# %%
# Write your code here.
species_types = penguins['species'].value_counts()
print(species_types)
target = 'species'
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %% [markdown]
# Plot histograms for the data

# %%
# Write your code here.
penguins = penguins.drop('rowid', axis=1)
_ = penguins.hist(figsize=(20, 14))

# %% [markdown]
# Show features distribution for each class. Hint: use
# [`seaborn.pairplot`](https://seaborn.pydata.org/generated/seaborn.pairplot.html). Pass in the entire dataframe as the 'data' (all columns). You can set the 'height' parameter to 4 and the 'hue' parameter to the species column. No other parameters in the pairplot need to be set.

# %%
# Write your code here.
import seaborn as sns
_ = sns.pairplot(data=penguins, hue=target, height=4)

# %% [markdown]
# Looking at these distributions, how hard do you think it would be to classify
# the penguins only using `"bill depth"` and `"bill length"`? Do certain values of `"bill depth"` and `"bill length"` correspond to certain species of penguin?

# %% [markdown]
#  Write your answer here - this should be text not code

# %% [markdown]
# Looking at these distributions, I don't think it would be too hard to classify penguins using only bill length and bill depth. In the visuals above, in the intersection between the two, there are almost very clear clusters differentiating the different clusters. I would say as a blanket rule that if the bill is between 33 and 40 mm long and greater than 15 mm wide, it is an Adelie, if it's greater than 40 mm long and above 18 mm wide, it's most likely a Chinstrap, if it's greater than 40 mm long and less than 16 mm wide, it's most likely a Gentoo. However, if its bill is longer than 40 mm long and between 16 and 18 mm wide, more information would be needed to discover its species.
